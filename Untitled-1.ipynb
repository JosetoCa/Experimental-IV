# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de la primera medida sobre el chiquito
voltajes = np.array([
    0.33, 0.351, 0.377, 0.398, 0.420, 0.442, 0.463, 0.482, 0.5, 
    0.515, 0.529, 0.541, 0.552, 0.562, 0.57, 0.578, 0.585, 0.59, 0.596,
    0.601, 0.606, 0.610,
    0.614, 0.617, 0.622,
    0.625, 0.629, 0.631,
    0.634, 0.637, 0.639,
    0.642, 0.644, 0.646,
    0.648, 0.65
])
corrientes = np.array([
   -0.001, -0.004, -0.008, -0.016, -0.028, -0.05, -0.083, -0.129, -0.193,
   -0.272, -0.374, -0.489, -0.617, -0.756, -0.909, -1.072, -1.238, -1.4, -1.584,
   -1.770, -1.962, -2.148,
    -2.348, -2.573, -2.738,
    -2.945, -3.152, -3.360,
    -3.560, -3.764, -3.976,
    -4.176, -4.381, -4.582,
    -4.804, -5.017
])

# Datos de la segunda medida sobre el chiquito

voltajes_3 = np.array([
    0.326, 0.350, 0.375, 0.400,
    0.423, 0.447, 0.472,
    0.495, 0.518, 0.540,
    0.563, 0.584, 0.601,
    0.618, 0.634, 0.648,
    0.660, 0.669, 0.679,
    0.687, 0.694, 0.700
])

corrientes_3 = np.array([
    0.00, 0.00, 0.00, 0.01,
    0.03, 0.05, 0.10,
    0.16, 0.28, 0.46,
    0.75, 1.17, 1.74,
    2.50, 3.51, 4.70,
    6.09, 7.53, 9.25,
    11.08, 13.06, 15.019
])

# Datos de la primera medida sobre el grande

import numpy as np

datos = np.array([
    [0.333, -0.008],
    [0.355, -0.016],
    [0.377, -0.029],
    [0.399, -0.053],
    [0.419, -0.090],
    [0.436, -0.142]
])

voltaje = datos[:, 0]
corriente = datos[:, 1]

import numpy as np

datos = np.array([
    [0.487, -0.255],
    [0.489, -0.301],
    [0.492, -0.524],
    [0.502, -0.662],
    [0.511, -0.807],
    [0.518, -0.960],
    [0.525, -1.119],
    [0.531, -1.290],
    [0.537, -1.467],
    [0.542, -1.646],
    [0.545, -1.792],
    [0.550, -1.987],
    [0.554, -2.177],
    [0.558, -2.371],
    [0.561, -2.551],
    [0.565, -2.747],
    [0.569, -2.933],
    [0.573, -3.141],
    [0.576, -3.547],
    [0.580, -3.744],
    [0.581, -3.989],
    [0.583, -4.143],
    [0.585, -4.350],
    [0.587, -4.493],
    [0.588, -4.688],
    [0.590, -4.890],
    [0.592, -5.100],
    [0.594, -5.315],
    [0.596, -5.532],
    [0.597, -5.743],
    [0.599, -5.964]
])

voltaje = datos[:, 0]
corriente = datos[:, 1]


#datos segunda medida del grande
import numpy as np

datos = np.array([
    [0.349,  0.00],
    [0.373, -0.01],
    [0.396, -0.02],
    [0.423, -0.05],
    [0.446, -0.10],
    [0.470, -0.18],
    [0.494, -0.32],
    [0.516, -0.53],
    [0.538, -0.85],
    [0.557, -1.30],
    [0.576, -1.97],
    [0.592, -2.80],
    [0.606, -3.81],
    [0.618, -4.99],
    [0.629, -6.35]
])

voltaje = datos[:, 0]
corriente = datos[:, 1]

import numpy as np

datos = np.array([
    [0.638,  7.87],
    [0.646,  9.44],
    [0.653, 11.01],
    [0.660, 12.8],
    [0.665, 14.65],
    [0.671, 16.59],
    [0.675, 18.53],
    [0.679, 20.57],
    [0.683, 22.51],
    [0.687, 24.51],
    [0.690, 26.55],
    [0.693, 28.63],
    [0.696, 30.75],
    [0.699, 32.79]
])

voltaje = datos[:, 0]
corriente = datos[:, 1]
