# %%
import numpy as np
# Función del coeficiente de expansión
def coe_dil(dl,l,dt):
    return dl/(l*dt)
# Función de la incertidumbre del coeficiente de expansión
def incer(alfa,dl,l,dt,il,idl,idt):
    return alfa*np.sqrt((il/l)**2 + (idl/dl)**2 + (idt/dt)**2)
# Resolución elonganción
idl = .01
# Resolución de la Longitud inicial
il = 1
# Resolución de la temperatura
idt = .1

# %%
# Longitud inicial
L_f = 701
# Elongación
dl_f = .59
# Temperatura incial
T_0 = 25.6
# Temperatura final bajo la aproximación 1.
T_f1 = 87.5
dt = T_f1-T_0
print("Bajo la aproximación de promediar las temperaturas finales de los sensores el coeficiente de dilatación térmica del hierro fue: "+f"{coe_dil(dl_f, L_f, dt):.2e}" + r' $\pm$ '  + f"{incer(coe_dil(dl_f, L_f, dt), dl_f, L_f, dt, il, idl, idt ):.0e}")
# Temperatura final bajo la aproximación 2.
T_f1 = 89.7
dt = T_f1-T_0
print("Bajo la aproximación de asumir la mayor temperatura medida como la final el coeficiente de dilatación térmica del hierro fue: "+f"{coe_dil(dl_f, L_f, dt):.2e}" + r' $\pm$ '  + f"{incer(coe_dil(dl_f, L_f, dt), dl_f, L_f, dt, il, idl, idt ):.0e}")
# Out:
# Bajo la aproximación de promediar las temperaturas finales de los sensores el coeficiente de dilatación térmica del hierro fue: 1.36e-05 $\pm$ 2e-07
# Bajo la aproximación de asumir la mayor temperatura medida como la final el coeficiente de dilatación térmica del hierro fue: 1.31e-05 $\pm$ 2e-07

# %%
L_f = 701
dl_f = .82
T_0 = 27.1
T_f1 = 87.2
dt = T_f1-T_0
print("Bajo la aproximación de promediar las temperaturas finales de los sensores el coeficiente de dilatación térmica del cobre fue: "+f"{coe_dil(dl_f, L_f, dt):.2e}" + r' $\pm$ '  + f"{incer(coe_dil(dl_f, L_f, dt), dl_f, L_f, dt, il, idl, idt ):.0e}")
T_f1 = 88.4
dt = T_f1-T_0
print("Bajo la aproximación de asumir la mayor temperatura medida como la final el coeficiente de dilatación térmica del cobre fue: "+f"{coe_dil(dl_f, L_f, dt):.2e}" + r' $\pm$ '  + f"{incer(coe_dil(dl_f, L_f, dt), dl_f, L_f, dt, il, idl, idt ):.0e}")
# Out:
# Bajo la aproximación de promediar las temperaturas finales de los sensores el coeficiente de dilatación térmica del cobre fue: 1.95e-05 $\pm$ 2e-07
# Bajo la aproximación de asumir la mayor temperatura medida como la final el coeficiente de dilatación térmica del cobre fue: 1.91e-05 $\pm$ 2e-07

# %%
L_f = 700
dl_f = 1.13
T_0 = 26.2
T_f1 = 86.65
dt = T_f1-T_0
print("Bajo la aproximación de promediar las temperaturas finales de los sensores el coeficiente de dilatación térmica del aluminio fue: "+f"{coe_dil(dl_f, L_f, dt):.2e}" + r' $\pm$ '  + f"{incer(coe_dil(dl_f, L_f, dt), dl_f, L_f, dt, il, idl, idt ):.0e}")
T_f1 = 87.9
dt = T_f1-T_0
print("Bajo la aproximación de asumir la mayor temperatura medida como la final el coeficiente de dilatación térmica del aluminio fue: "+f"{coe_dil(dl_f, L_f, dt):.2e}" + r' $\pm$ '  + f"{incer(coe_dil(dl_f, L_f, dt), dl_f, L_f, dt, il, idl, idt ):.0e}")
# Out:
# Bajo la aproximación de promediar las temperaturas finales de los sensores el coeficiente de dilatación térmica del aluminio fue: 2.67e-05 $\pm$ 2e-07
# Bajo la aproximación de asumir la mayor temperatura medida como la final el coeficiente de dilatación térmica del aluminio fue: 2.62e-05 $\pm$ 2e-07
